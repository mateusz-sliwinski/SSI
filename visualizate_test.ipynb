# %%
import visualizate
import importlib
import matplotlib.pyplot as plt
import visualizate as vis
importlib.reload(visualizate)

plt.plot([1, 2, 3, 4])
vis.clean_plot()

# %%
vis.draw_dashed_plot([0, 2], [14])

# %%
vis.draw_sin_plot([-1, 1, 100])

# %%
vis.draw_dot_plot([-1, 0, 1], [0.75, 0, 0.75])

# %%
vis.draw_face([0, 2], [14], [-1, 0, 1], [0.75, 0, 0.75], [-1, 1, 100])
